# %%
import json
import urllib.request
import time
import matplotlib.pyplot as plt

lonList=[]
latList=[]
timestampList=[]

for i in range(100):
    url = "http://api.open-notify.org/iss-now.json"
    response = urllib.request.urlopen(url)
    result = json.loads(response.read())
    location = result["iss_position"]
    timestamp = result['timestamp']
    lon = location['longitude']
    lat = location['latitude']
    lon = float(lon)
    lat = float(lat)
    lonList.append(lon)
    latList.append(lat)
    timestampList.append(timestamp)
    time.sleep(10)

import pandas as pd
d = {'latitude': latList, 'longitude': lonList, 'timestamp': timestampList}
df = pd.DataFrame(data=d)
df
# Out:
#     latitude  longitude   timestamp
# 0    25.1466  -104.8600  1658818085
# 1    24.6503  -104.3909  1658818095
# 2    24.1524  -103.9258  1658818106
# 3    23.6528  -103.4649  1658818116
# 4    23.1515  -103.0076  1658818127
# ..       ...        ...         ...
# 95  -24.8379   -65.8058  1658819094
# 96  -25.3322   -65.3365  1658819105
# 97  -25.8247   -64.8630  1658819115
# 98  -26.3152   -64.3853  1658819126
# 99  -26.8270   -63.8801  1658819137
#
# [100 rows x 3 columns]

# %%
fig = plt.figure(figsize=(30,20))
ax = fig.add_subplot()
ax.scatter(latList,lonList)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
ax.set_xlim([-90, 90])
ax.set_xlim([-180, 180])
# Out:
# (-180.0, 180.0)
